# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"D:\Data Science New\archive (2)\Sales_data.csv")
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#              ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0    2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05-07-2003 00:00  Shipped       2         5     2003  ...
# 2  07-01-2003 00:00  Shipped       3         7     2003  ...
# 3    8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10-10-2003 00:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df["TERRITORY"].dtype
# Out:
# dtype('O')

# %%
df["ADDRESSLINE2"].dtype
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df["TERRITORY"].head()
# Out:
# 0     NaN
# 1    EMEA
# 2    EMEA
# 3     NaN
# 4     NaN
# Name: TERRITORY, dtype: object

# %%
df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2818        False            False      False            False  False
# 2819        False            False      False            False  False
# 2820        False            False      False            False  False
# 2821        False            False      False            False  False
# 2822        False            False      False            False  False
#
#       ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  ADDRESSLINE1  \
# ...

# %%
df["STATE"].head
# Out:
# <bound method NDFrame.head of 0        NY
# 1       NaN
# 2       NaN
# 3        CA
# 4        CA
#        ...
# 2818    NaN
# 2819    NaN
# 2820    NaN
# 2821    NaN
# 2822     MA
# Name: STATE, Length: 2823, dtype: object>

# %%
df["STATE"]=df["STATE"].fillna(method="bfill")
# Out:
# C:\Users\Sahil\AppData\Local\Temp\ipykernel_17900\1900653690.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["STATE"]=df["STATE"].fillna(method="bfill")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE                  0
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df["POSTALCODE"]=df["POSTALCODE"].fillna(method="bfill")
# Out:
# C:\Users\Sahil\AppData\Local\Temp\ipykernel_17900\4069359262.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["POSTALCODE"]=df["POSTALCODE"].fillna(method="bfill")

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE                  0
# POSTALCODE             0
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df["SALES"].mean()
# Out:
# np.float64(3553.889071909316)

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.groupby('STATE')["SALES"].mean()
# Out:
# STATE
# BC               3298.393289
# CA               3557.394667
# CT               3709.343393
# Isle of Wight    3323.286667
# MA               3562.841908
# NH               3911.695370
# NJ               3733.694468
# NSW              3514.770507
# NV               3202.788370
# NY               3518.734196
# Osaka            3845.802571
# PA               3747.181667
# Quebec           3714.792000
# Queensland       3732.319565
# Tokyo            3442.120000
# Victoria         3494.523130
# Name: SALES, dtype: float64

# %%
df["SALES"].mean()
# Out:
# np.float64(3553.889071909316)

# %%
df["SALES"].max()
# Out:
# 14082.8

# %%
df["SALES"].min()
# Out:
# 482.13

# %%
df["SALES"].plot(kind='hist')

plt.show()

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0    2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05-07-2003 00:00  Shipped       2         5     2003  ...
# 2  07-01-2003 00:00  Shipped       3         7     2003  ...
# 3    8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10-10-2003 00:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df["STATUS"].unique
# Out:
# <bound method Series.unique of 0        Shipped
# 1        Shipped
# 2        Shipped
# 3        Shipped
# 4        Shipped
#           ...
# 2818     Shipped
# 2819     Shipped
# 2820    Resolved
# 2821     Shipped
# 2822     On Hold
# Name: STATUS, Length: 2823, dtype: object>

# %%
df.groupby("QUANTITYORDERED")["SALES"].sum().sort_values(ascending=False)
# Out:
# QUANTITYORDERED
# 46    479822.28
# 49    447756.61
# 48    446526.74
# 41    441080.87
# 45    435189.15
# 44    383114.16
# 43    380780.87
# 34    375930.52
# 38    361377.34
# 47    351746.61
# 50    344809.00
# 36    328273.92
# 37    326312.25
# 33    314508.48
# 42    314140.26
# 39    308742.72
# 40    305109.20
# 27    290757.06
# 32    289364.80
# 29    282519.74
# 31    278135.41
# 26    251397.90
# 25    232165.25
# 35    230680.10
# 22    224993.12
# 28    224454.44
# 24    220617.84
# 21    215406.03
# 30    211356.00
# 20    192172.60
# 23    174389.68
# 55     88818.95
# 66     38607.36
# 76     33004.50
# 60     21875.40
# 51     18230.46
# 59     18036.89
# 70     17738.00
# 56     16695.84
# 64     16080.64
# 61     14685.75
# 54     13133.34
# 65     10468.90
# 97      9048.16
# 85      7543.75
# 58      7307.42
# 77      7084.00
# 62      4819.26
# 19      4625.36
# 18      4501.62
# 52      4219.28
# 15      3328.95
# 10      1973.60
# 12      1961.28
# ...

# %%
df.groupby("COUNTRY")["SALES"].sum().sort_values(ascending=False)
# Out:
# COUNTRY
# USA            3627982.83
# Spain          1215686.92
# France         1110916.52
# Australia       630623.10
# UK              478880.46
# Italy           374674.31
# Finland         329581.91
# Norway          307463.70
# Singapore       288488.41
# Denmark         245637.15
# Canada          224078.56
# Germany         220472.09
# Sweden          210014.21
# Austria         202062.53
# Japan           188167.81
# Switzerland     117713.56
# Belgium         108412.62
# Philippines      94015.73
# Ireland          57756.43
# Name: SALES, dtype: float64

# %%
df.groupby("MONTH_ID")["SALES"].sum().sort_values(ascending=False)
# Out:
# MONTH_ID
# 11    2118885.67
# 10    1121215.22
# 5      923972.56
# 2      810441.90
# 1      785874.44
# 3      754501.39
# 4      669390.96
# 8      659310.57
# 12     634679.12
# 9      584724.27
# 7      514875.97
# 6      454756.78
# Name: SALES, dtype: float64

# %%
import seaborn as sns

# %%
numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(numeric_df.corr(), annot=True)
# Out:
# <Axes: >

# %%
max_sale_country=df.groupby("COUNTRY")["SALES"].sum()

# %%
df.groupby("SALES")["QUANTITYORDERED"].sum().min()
# Out:
# 6

# %%
Sales_Monthly=df.groupby("MONTH_ID")["SALES"].sum()

# %%
Sales_Monthly.plot(kind="bar")
# Out:
# <Axes: xlabel='MONTH_ID'>

# %%
max_sale_country.plot(kind="bar")
# Out:
# <Axes: xlabel='COUNTRY'>

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

x=df[["QUANTITYORDERED","PRICEEACH","MSRP","MONTH_ID","YEAR_ID"]]
y=df["SALES"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 653.0008886478494
# R2 Score: 0.7605484090559735

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_prectict=rf.predict(x_test)

# %%
print("MAE: ",mean_absolute_error(y_test,rf_prectict))
print("R2 Score:", r2_score(y_test, rf_prectict))
# Out:
# MAE:  325.15722793341746
# R2 Score: 0.8842654707495294

# %%
import joblib
joblib.dump(rf,"Sales_model.pkl")
# Out:
# ['Sales_model.pkl']
